# %%
# docs and experiment results can be found at https://docs.cleanrl.dev/rl-algorithms/dqn/#dqnpy
import os
import random
import time
from dataclasses import dataclass

import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tyro
from stable_baselines3.common.buffers import ReplayBuffer
from torch.utils.tensorboard import SummaryWriter


@dataclass
class Args:
    exp_name: str = "dqn"
    """the name of this experiment"""
    seed: int = 1
    """seed of the experiment"""
    torch_deterministic: bool = True
    """if toggled, `torch.backends.cudnn.deterministic=False`"""
    cuda: bool = True
    """if toggled, cuda will be enabled by default"""
    track: bool = False
    """if toggled, this experiment will be tracked with Weights and Biases"""
    wandb_project_name: str = "cleanRL"
    """the wandb's project name"""
    wandb_entity: str = None
    """the entity (team) of wandb's project"""
    capture_video: bool = False
    """whether to capture videos of the agent performances (check out `videos` folder)"""
    save_model: bool = True
    """whether to save model into the `runs/{run_name}` folder"""
    upload_model: bool = False
    """whether to upload the saved model to huggingface"""
    hf_entity: str = ""
    """the user or org name of the model repository from the Hugging Face Hub"""

    # Algorithm specific arguments
    env_id: str = "CartPole-v1"
    """the id of the environment"""
    total_timesteps: int = 300000
    """total timesteps of the experiments"""
    learning_rate: float = 2.5e-4
    """the learning rate of the optimizer"""
    num_envs: int = 1
    """the number of parallel game environments"""
    buffer_size: int = 10000
    """the replay memory buffer size"""
    gamma: float = 0.99
    """the discount factor gamma"""
    tau: float = 1.0
    """the target network update rate"""
    target_network_frequency: int = 500
    """the timesteps it takes to update the target network"""
    batch_size: int = 128
    """the batch size of sample from the reply memory"""
    start_e: float = 1
    """the starting epsilon for exploration"""
    end_e: float = 0.05
    """the ending epsilon for exploration"""
    exploration_fraction: float = 0.5
    """the fraction of `total-timesteps` it takes from start-e to go end-e"""
    learning_starts: int = 10000
    """timestep to start learning"""
    train_frequency: int = 10
    """the frequency of training"""

# %%
def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        if capture_video and idx == 0:
            env = gym.make(env_id, render_mode="rgb_array")
            env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        else:
            env = gym.make(env_id)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        env.action_space.seed(seed)

        return env

    return thunk

# %%
# ALGO LOGIC: initialize agent here:
class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(np.array(env.single_observation_space.shape).prod(), 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, env.single_action_space.n),
        )

    def forward(self, x):
        return self.network(x)

# %%
def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope = (end_e - start_e) / duration
    return max(slope * t + start_e, end_e)

# %%
import stable_baselines3 as sb3

if sb3.__version__ < "2.0":
    raise ValueError(
        """Ongoing migration: run the following command to install the new dependencies:

poetry run pip install "stable_baselines3==2.0.0a1"
"""
    )

# args = tyro.cli(Args)
args = Args()
assert args.num_envs == 1, "vectorized envs are not supported at the moment"
run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
if args.track:
    import wandb

    wandb.init(
        project=args.wandb_project_name,
        entity=args.wandb_entity,
        sync_tensorboard=True,
        config=vars(args),
        name=run_name,
        monitor_gym=True,
        save_code=True,
    )

# %%
writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s"
    % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# %%
# TRY NOT TO MODIFY: seeding
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")
print(device)
# Out:
# cuda

# %%
# env setup
envs = gym.vector.SyncVectorEnv(
    [
        make_env(args.env_id, args.seed + i, i, args.capture_video, run_name)
        for i in range(args.num_envs)
    ]
)
assert isinstance(
    envs.single_action_space, gym.spaces.Discrete
), "only discrete action space is supported"

q_network = QNetwork(envs).to(device)
optimizer = optim.Adam(q_network.parameters(), lr=args.learning_rate)
target_network = QNetwork(envs).to(device)
target_network.load_state_dict(q_network.state_dict())
# Out:
# <All keys matched successfully>

# %%
rb = ReplayBuffer(
    args.buffer_size,
    envs.single_observation_space,
    envs.single_action_space,
    device,
    handle_timeout_termination=False,
)
start_time = time.time()

# TRY NOT TO MODIFY: start the game
obs, _ = envs.reset(seed=args.seed)
for global_step in range(args.total_timesteps):
    # ALGO LOGIC: put action logic here
    epsilon = linear_schedule(
        args.start_e,
        args.end_e,
        args.exploration_fraction * args.total_timesteps,
        global_step,
    )
    if random.random() < epsilon:
        actions = np.array(
            [envs.single_action_space.sample() for _ in range(envs.num_envs)]
        )
    else:
        q_values = q_network(torch.Tensor(obs).to(device))
        actions = torch.argmax(q_values, dim=1).cpu().numpy()

    # TRY NOT TO MODIFY: execute the game and log data.
    next_obs, rewards, terminations, truncations, infos = envs.step(actions)

    # TRY NOT TO MODIFY: record rewards for plotting purposes
    if "final_info" in infos:
        for info in infos["final_info"]:
            if info and "episode" in info:
                print(
                    f"global_step={global_step}, episodic_return={info['episode']['r']}"
                )
                writer.add_scalar(
                    "charts/episodic_return", info["episode"]["r"], global_step
                )
                writer.add_scalar(
                    "charts/episodic_length", info["episode"]["l"], global_step
                )

    # TRY NOT TO MODIFY: save data to reply buffer; handle `final_observation`
    real_next_obs = next_obs.copy()
    for idx, trunc in enumerate(truncations):
        if trunc:
            real_next_obs[idx] = infos["final_observation"][idx]
    rb.add(obs, real_next_obs, actions, rewards, terminations, infos)

    # TRY NOT TO MODIFY: CRUCIAL step easy to overlook
    obs = next_obs

    # ALGO LOGIC: training.
    if global_step > args.learning_starts:
        if global_step % args.train_frequency == 0:
            data = rb.sample(args.batch_size)
            with torch.no_grad():
                target_max, _ = target_network(data.next_observations).max(dim=1)
                td_target = data.rewards.flatten() + args.gamma * target_max * (
                    1 - data.dones.flatten()
                )
            old_val = q_network(data.observations).gather(1, data.actions).squeeze()
            loss = F.mse_loss(td_target, old_val)

            if global_step % 100 == 0:
                writer.add_scalar("losses/td_loss", loss, global_step)
                writer.add_scalar("losses/q_values", old_val.mean().item(), global_step)
                print("SPS:", int(global_step / (time.time() - start_time)))
                writer.add_scalar(
                    "charts/SPS",
                    int(global_step / (time.time() - start_time)),
                    global_step,
                )

            # optimize the model
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # update target network
        if global_step % args.target_network_frequency == 0:
            for target_network_param, q_network_param in zip(
                target_network.parameters(), q_network.parameters()
            ):
                target_network_param.data.copy_(
                    args.tau * q_network_param.data
                    + (1.0 - args.tau) * target_network_param.data
                )
# Out:
# global_step=28, episodic_return=[29.]
# global_step=38, episodic_return=[10.]
# global_step=49, episodic_return=[11.]
# global_step=85, episodic_return=[36.]
# global_step=98, episodic_return=[13.]
# global_step=114, episodic_return=[16.]
# global_step=131, episodic_return=[17.]
# global_step=150, episodic_return=[19.]
# global_step=187, episodic_return=[37.]
# global_step=214, episodic_return=[27.]
# global_step=229, episodic_return=[15.]
# global_step=242, episodic_return=[13.]
# global_step=265, episodic_return=[23.]
# global_step=275, episodic_return=[10.]
# global_step=304, episodic_return=[29.]
# global_step=322, episodic_return=[18.]
# global_step=333, episodic_return=[11.]
# global_step=344, episodic_return=[11.]
# global_step=390, episodic_return=[46.]
# global_step=401, episodic_return=[11.]
# global_step=433, episodic_return=[32.]
# global_step=480, episodic_return=[47.]
# global_step=496, episodic_return=[16.]
# global_step=522, episodic_return=[26.]
# global_step=556, episodic_return=[34.]
# global_step=572, episodic_return=[16.]
# global_step=591, episodic_return=[19.]
# global_step=613, episodic_return=[22.]
# global_step=637, episodic_return=[24.]
# global_step=652, episodic_return=[15.]
# global_step=663, episodic_return=[11.]
# global_step=680, episodic_return=[17.]
# SPS: 2238
# SPS: 2238
# global_step=237374, episodic_return=[500.]
# SPS: 2237
# SPS: 2237
# SPS: 2237
# SPS: 2237
# SPS: 2236
# global_step=237874, episodic_return=[500.]
# SPS: 2236
# SPS: 2236
# SPS: 2236
# SPS: 2235
# SPS: 2235
# global_step=238374, episodic_return=[500.]
# SPS: 2235
# SPS: 2234
# SPS: 2234
# SPS: 2234
# SPS: 2234
# global_step=238874, episodic_return=[500.]
# SPS: 2233
# SPS: 2233
# SPS: 2233
# SPS: 2233
# SPS: 2232
# global_step=239374, episodic_return=[500.]
# SPS: 2232
# SPS: 2232
# SPS: 2232
# SPS: 2232
# SPS: 2231
# global_step=239874, episodic_return=[500.]
# SPS: 2231
# SPS: 2231
# SPS: 2231
# SPS: 2230
# SPS: 2230
# global_step=240374, episodic_return=[500.]
# SPS: 2230
# SPS: 2230
# SPS: 2229
# SPS: 2229
# SPS: 2229
# global_step=240874, episodic_return=[500.]
# SPS: 2229
# SPS: 2228
# SPS: 2228
# SPS: 2228
# SPS: 2228
# global_step=241374, episodic_return=[500.]
# SPS: 2227
# SPS: 2227
# SPS: 2227
# SPS: 2227
# SPS: 2226
# global_step=241874, episodic_return=[500.]
# SPS: 2226
# SPS: 2226
# SPS: 2226
# SPS: 2225
# SPS: 2225
# global_step=242374, episodic_return=[500.]
# SPS: 2225
# SPS: 2225
# SPS: 2225
# SPS: 2224
# SPS: 2224
# global_step=242874, episodic_return=[500.]
# SPS: 2224
# SPS: 2224
# SPS: 2223
# SPS: 2223
# SPS: 2223
# global_step=243374, episodic_return=[500.]
# SPS: 2223
# SPS: 2223
# SPS: 2222
# SPS: 2222
# SPS: 2222
# global_step=243874, episodic_return=[500.]
# SPS: 2222
# SPS: 2221
# SPS: 2221
# SPS: 2221
# SPS: 2221
# global_step=244374, episodic_return=[500.]
# SPS: 2221
# SPS: 2220
# SPS: 2220
# SPS: 2220
# SPS: 2220
# global_step=244874, episodic_return=[500.]
# SPS: 2219
# SPS: 2219
# SPS: 2219
# SPS: 2219
# SPS: 2219
# global_step=245374, episodic_return=[500.]
# SPS: 2218
# SPS: 2218
# SPS: 2218
# SPS: 2218
# SPS: 2217
# global_step=245874, episodic_return=[500.]
# SPS: 2217
# SPS: 2217
# SPS: 2217
# SPS: 2217
# SPS: 2216
# global_step=246374, episodic_return=[500.]
# SPS: 2216
# SPS: 2216
# SPS: 2216
# SPS: 2215
# SPS: 2215
# global_step=246874, episodic_return=[500.]
# SPS: 2215
# SPS: 2215
# SPS: 2215
# SPS: 2214
# SPS: 2214
# global_step=247374, episodic_return=[500.]
# SPS: 2214
# SPS: 2214
# SPS: 2213
# SPS: 2213
# SPS: 2213
# global_step=247874, episodic_return=[500.]
# SPS: 2213
# SPS: 2212
# SPS: 2212
# SPS: 2212
# SPS: 2212
# global_step=248374, episodic_return=[500.]
# SPS: 2212
# SPS: 2211
# SPS: 2211
# SPS: 2211
# SPS: 2210
# global_step=248874, episodic_return=[500.]
# SPS: 2210
# SPS: 2209
# SPS: 2209
# SPS: 2209
# SPS: 2180
# global_step=261364, episodic_return=[500.]
# SPS: 2180
# SPS: 2179
# SPS: 2179
# SPS: 2179
# SPS: 2179
# global_step=261864, episodic_return=[500.]
# SPS: 2178
# SPS: 2178
# SPS: 2178
# SPS: 2178
# SPS: 2178
# global_step=262364, episodic_return=[500.]
# SPS: 2177
# SPS: 2177
# SPS: 2177
# SPS: 2177
# SPS: 2177
# global_step=262864, episodic_return=[500.]
# SPS: 2176
# SPS: 2176
# SPS: 2176
# SPS: 2176
# SPS: 2176
# global_step=263364, episodic_return=[500.]
# SPS: 2175
# SPS: 2175
# SPS: 2175
# SPS: 2175
# SPS: 2174
# global_step=263864, episodic_return=[500.]
# SPS: 2174
# SPS: 2174
# SPS: 2174
# SPS: 2174
# SPS: 2173
# global_step=264364, episodic_return=[500.]
# SPS: 2173
# SPS: 2173
# SPS: 2173
# SPS: 2173
# SPS: 2172
# global_step=264864, episodic_return=[500.]
# SPS: 2172
# SPS: 2172
# SPS: 2172
# SPS: 2172
# SPS: 2171
# global_step=265344, episodic_return=[480.]
# SPS: 2171
# SPS: 2171
# SPS: 2171
# SPS: 2171
# SPS: 2170
# global_step=265844, episodic_return=[500.]
# SPS: 2170
# SPS: 2170
# SPS: 2170
# SPS: 2170
# SPS: 2170
# global_step=266344, episodic_return=[500.]
# SPS: 2169
# SPS: 2169
# SPS: 2169
# SPS: 2169
# SPS: 2169
# global_step=266844, episodic_return=[500.]
# SPS: 2168
# SPS: 2168
# SPS: 2168
# SPS: 2168
# SPS: 2168
# global_step=267344, episodic_return=[500.]
# SPS: 2168
# SPS: 2168
# SPS: 2167
# SPS: 2167
# SPS: 2167
# global_step=267844, episodic_return=[500.]
# SPS: 2167
# SPS: 2166
# SPS: 2166
# SPS: 2166
# SPS: 2166
# global_step=268344, episodic_return=[500.]
# SPS: 2166
# SPS: 2165
# SPS: 2165
# SPS: 2165
# SPS: 2165
# global_step=268844, episodic_return=[500.]
# SPS: 2165
# SPS: 2164
# SPS: 2164
# SPS: 2164
# SPS: 2164
# global_step=269344, episodic_return=[500.]
# SPS: 2164
# SPS: 2163
# SPS: 2163
# SPS: 2163
# SPS: 2163
# global_step=269844, episodic_return=[500.]
# SPS: 2163
# SPS: 2162
# SPS: 2162
# SPS: 2162
# SPS: 2162
# global_step=270344, episodic_return=[500.]
# SPS: 2162
# SPS: 2161
# SPS: 2161
# SPS: 2161
# SPS: 2161
# global_step=270844, episodic_return=[500.]
# SPS: 2161
# SPS: 2161
# SPS: 2160
# SPS: 2160
# SPS: 2160
# global_step=271344, episodic_return=[500.]
# SPS: 2160
# SPS: 2160
# SPS: 2159
# SPS: 2159
# SPS: 2159
# global_step=271844, episodic_return=[500.]
# SPS: 2159
# SPS: 2158
# SPS: 2158
# SPS: 2158
# SPS: 2158
# global_step=272344, episodic_return=[500.]
# SPS: 2157
# SPS: 2157
# SPS: 2157
# SPS: 2157
# SPS: 2157
# global_step=272844, episodic_return=[500.]
# SPS: 2157
# SPS: 2156
# SPS: 2156
# SPS: 2156
# SPS: 2156
# global_step=273344, episodic_return=[500.]
# SPS: 2155
# SPS: 2155
# SPS: 2155
# SPS: 2155
# SPS: 2155
# global_step=273844, episodic_return=[500.]
# SPS: 2154
# SPS: 2154
# SPS: 2154
# SPS: 2154
# SPS: 2154
# global_step=274344, episodic_return=[500.]
# SPS: 2153
# SPS: 2153
# SPS: 2153
# SPS: 2153
# SPS: 2153
# global_step=274844, episodic_return=[500.]
# SPS: 2153
# SPS: 2152
# SPS: 2152
# SPS: 2152
# SPS: 2152
# global_step=275344, episodic_return=[500.]
# SPS: 2152
# SPS: 2152
# SPS: 2151
# SPS: 2151
# SPS: 2151
# global_step=275844, episodic_return=[500.]
# SPS: 2150
# SPS: 2150
# SPS: 2150
# SPS: 2149
# SPS: 2149
# global_step=276344, episodic_return=[500.]
# SPS: 2148
# SPS: 2148
# SPS: 2148
# SPS: 2148
# SPS: 2147
# global_step=276844, episodic_return=[500.]
# SPS: 2147
# SPS: 2147
# SPS: 2147
# SPS: 2146
# SPS: 2146
# global_step=277344, episodic_return=[500.]
# SPS: 2146
# SPS: 2146
# SPS: 2145
# SPS: 2145
# SPS: 2145
# global_step=277844, episodic_return=[500.]
# SPS: 2145
# SPS: 2145
# SPS: 2145
# SPS: 2145
# SPS: 2145
# global_step=278344, episodic_return=[500.]
# SPS: 2144
# SPS: 2144
# SPS: 2144
# SPS: 2144
# SPS: 2144
# global_step=278844, episodic_return=[500.]
# SPS: 2144
# SPS: 2144
# SPS: 2143
# SPS: 2143
# SPS: 2143
# global_step=279344, episodic_return=[500.]
# SPS: 2143
# SPS: 2143
# SPS: 2142
# SPS: 2142
# SPS: 2142
# global_step=279844, episodic_return=[500.]
# SPS: 2142
# SPS: 2142
# SPS: 2141
# SPS: 2141
# SPS: 2141
# global_step=280344, episodic_return=[500.]
# SPS: 2141
# SPS: 2141
# SPS: 2140
# SPS: 2140
# SPS: 2140
# global_step=280844, episodic_return=[500.]
# SPS: 2140
# SPS: 2140
# SPS: 2140
# SPS: 2140
# SPS: 2140
# global_step=281344, episodic_return=[500.]
# SPS: 2139
# SPS: 2139
# SPS: 2139
# SPS: 2139
# SPS: 2139
# global_step=281844, episodic_return=[500.]
# SPS: 2138
# SPS: 2138
# SPS: 2138
# SPS: 2138
# SPS: 2138
# global_step=282344, episodic_return=[500.]
# SPS: 2138
# SPS: 2137
# SPS: 2137
# SPS: 2137
# SPS: 2137
# global_step=282844, episodic_return=[500.]
# SPS: 2137
# SPS: 2137
# SPS: 2137
# SPS: 2136
# SPS: 2136
# global_step=283344, episodic_return=[500.]
# SPS: 2136
# SPS: 2136
# SPS: 2136
# SPS: 2136
# SPS: 2135
# global_step=283844, episodic_return=[500.]
# SPS: 2135
# SPS: 2135
# SPS: 2135
# SPS: 2135
# SPS: 2135
# global_step=284344, episodic_return=[500.]
# SPS: 2134
# SPS: 2134
# SPS: 2134
# SPS: 2134
# SPS: 2134
# global_step=284844, episodic_return=[500.]
# SPS: 2134
# SPS: 2133
# SPS: 2133
# SPS: 2133
# SPS: 2133
# global_step=285344, episodic_return=[500.]
# SPS: 2133
# SPS: 2133
# SPS: 2132
# SPS: 2132
# SPS: 2132
# global_step=285844, episodic_return=[500.]
# SPS: 2132
# SPS: 2132
# SPS: 2132
# SPS: 2131
# SPS: 2131
# global_step=286344, episodic_return=[500.]
# SPS: 2131
# SPS: 2131
# SPS: 2131
# SPS: 2131
# SPS: 2130
# global_step=286844, episodic_return=[500.]
# SPS: 2130
# SPS: 2130
# SPS: 2130
# SPS: 2130
# SPS: 2129
# global_step=287344, episodic_return=[500.]
# SPS: 2129
# SPS: 2129
# SPS: 2129
# SPS: 2129
# SPS: 2128
# global_step=287844, episodic_return=[500.]
# SPS: 2128
# SPS: 2128
# SPS: 2127
# SPS: 2127
# SPS: 2127
# global_step=288344, episodic_return=[500.]
# SPS: 2127
# SPS: 2127
# SPS: 2127
# SPS: 2126
# SPS: 2126
# global_step=288844, episodic_return=[500.]
# SPS: 2126
# SPS: 2126
# SPS: 2126
# SPS: 2126
# SPS: 2125
# global_step=289344, episodic_return=[500.]
# SPS: 2125
# SPS: 2125
# SPS: 2125
# SPS: 2125
# SPS: 2125
# global_step=289844, episodic_return=[500.]
# SPS: 2125
# SPS: 2125
# SPS: 2124
# SPS: 2124
# SPS: 2124
# global_step=290344, episodic_return=[500.]
# SPS: 2124
# SPS: 2124
# SPS: 2124
# SPS: 2124
# SPS: 2123
# global_step=290844, episodic_return=[500.]
# SPS: 2123
# SPS: 2123
# SPS: 2123
# SPS: 2123
# SPS: 2123
# global_step=291344, episodic_return=[500.]
# SPS: 2123
# SPS: 2122
# SPS: 2122
# SPS: 2122
# SPS: 2122
# global_step=291844, episodic_return=[500.]
# SPS: 2122
# SPS: 2122
# SPS: 2122
# SPS: 2121
# SPS: 2121
# global_step=292344, episodic_return=[500.]
# SPS: 2121
# SPS: 2121
# SPS: 2121
# SPS: 2120
# SPS: 2120
# global_step=292844, episodic_return=[500.]
# SPS: 2120
# SPS: 2120
# SPS: 2120
# SPS: 2120
# SPS: 2119
# global_step=293344, episodic_return=[500.]
# SPS: 2119
# SPS: 2119
# SPS: 2119
# SPS: 2119
# SPS: 2119
# global_step=293844, episodic_return=[500.]
# SPS: 2118
# SPS: 2118
# SPS: 2118
# SPS: 2118
# SPS: 2118
# global_step=294344, episodic_return=[500.]
# SPS: 2118
# SPS: 2118
# SPS: 2117
# SPS: 2117
# SPS: 2117
# global_step=294844, episodic_return=[500.]
# SPS: 2117
# SPS: 2117
# SPS: 2117
# SPS: 2117
# SPS: 2116
# global_step=295344, episodic_return=[500.]
# SPS: 2116
# SPS: 2116
# SPS: 2116
# SPS: 2116
# SPS: 2116
# global_step=295839, episodic_return=[495.]
# SPS: 2115
# SPS: 2115
# SPS: 2115
# SPS: 2115
# SPS: 2115
# global_step=296339, episodic_return=[500.]
# SPS: 2115
# SPS: 2115
# SPS: 2114
# SPS: 2114
# SPS: 2114
# global_step=296839, episodic_return=[500.]
# SPS: 2114
# SPS: 2114
# SPS: 2113
# SPS: 2113
# SPS: 2113
# global_step=297339, episodic_return=[500.]
# SPS: 2113
# SPS: 2112
# SPS: 2112
# SPS: 2112
# SPS: 2112
# global_step=297839, episodic_return=[500.]
# SPS: 2111
# SPS: 2111
# SPS: 2111
# SPS: 2111
# SPS: 2110
# global_step=298339, episodic_return=[500.]
# SPS: 2110
# SPS: 2110
# SPS: 2110
# SPS: 2109
# SPS: 2109
# global_step=298839, episodic_return=[500.]
# SPS: 2109
# SPS: 2109
# SPS: 2109
# SPS: 2108
# SPS: 2108
# global_step=299339, episodic_return=[500.]
# SPS: 2108
# SPS: 2108
# SPS: 2108
# SPS: 2107
# SPS: 2107
# global_step=299839, episodic_return=[500.]
# SPS: 2107
# SPS: 2107
# global_step=300041, episodic_return=[202.]
# SPS: 2106
# SPS: 2106
# SPS: 2106
# SPS: 2106
# SPS: 2105
# global_step=300541, episodic_return=[500.]
# SPS: 2105
# SPS: 2105
# SPS: 2105
# SPS: 2105
# SPS: 2105
# global_step=301041, episodic_return=[500.]
# SPS: 2104
# SPS: 2104
# SPS: 2104
# SPS: 2104
# SPS: 2104
# global_step=301541, episodic_return=[500.]
# SPS: 2104
# SPS: 2104
# SPS: 2104
# SPS: 2103
# SPS: 2103
# global_step=302041, episodic_return=[500.]
# SPS: 2103
# SPS: 2103
# SPS: 2103
# SPS: 2103
# SPS: 2103
# global_step=302541, episodic_return=[500.]
# SPS: 2102
# SPS: 2102
# SPS: 2102
# SPS: 2102
# SPS: 2102
# global_step=303041, episodic_return=[500.]
# SPS: 2102
# SPS: 2102
# SPS: 2102
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 29
#      26     actions = torch.argmax(q_values, dim=1).cpu().numpy()
#      28 # TRY NOT TO MODIFY: execute the game and log data.
# ---> 29 next_obs, rewards, terminations, truncations, infos = envs.step(actions)
#      31 # TRY NOT TO MODIFY: record rewards for plotting purposes
#      32 if "final_info" in infos:
#
# File ~/Git/rn-group-7/rl-demos/.venv/lib/python3.10/site-packages/gymnasium/vector/vector_env.py:203, in VectorEnv.step(self, actions)
#     168 """Take an action for each parallel environment.
#     169
#     170 Args:
#    (...)
#     200     {}
#     201 """
#     202 self.step_async(actions)
# --> 203 return self.step_wait()
#
# File ~/Git/rn-group-7/rl-demos/.venv/lib/python3.10/site-packages/gymnasium/vector/sync_vector_env.py:149, in SyncVectorEnv.step_wait(self)
#     141 observations, infos = [], {}
#     142 for i, (env, action) in enumerate(zip(self.envs, self._actions)):
#     143     (
#     144         observation,
#     145         self._rewards[i],
#     146         self._terminateds[i],
#     147         self._truncateds[i],
#     148         info,
# --> 149     ) = env.step(action)
#     151     if self._terminateds[i] or self._truncateds[i]:
#     152         old_observation, old_info = observation, info
#
# File ~/Git/rn-group-7/rl-demos/.venv/lib/python3.10/site-packages/gymnasium/wrappers/record_episode_statistics.py:96, in RecordEpisodeStatistics.step(self, action)
#      94 self.episode_lengths += 1
#      95 dones = np.logical_or(terminations, truncations)
# ---> 96 num_dones = np.sum(dones)
#      97 if num_dones:
#      98     if "episode" in infos or "_episode" in infos:
#
# File <__array_function__ internals>:200, in sum(*args, **kwargs)
#
# File ~/Git/rn-group-7/rl-demos/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2324, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2321         return out
#    2322     return res
# -> 2324 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2325                       initial=initial, where=where)
#
# File ~/Git/rn-group-7/rl-demos/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:69, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#      60         # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64         # Call _wrapit from within the except clause to ensure a potential
#      65         # exception has a traceback chain.
#      66         return _wrapit(obj, method, *args, **kwds)
# ---> 69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#      73     if type(obj) is not mu.ndarray:
#
# KeyboardInterrupt:

# %%
import random
from typing import Callable

import gymnasium as gym
import numpy as np
import torch


def evaluate(
    model_path: str,
    make_env: Callable,
    env_id: str,
    eval_episodes: int,
    run_name: str,
    Model: torch.nn.Module,
    device: torch.device = torch.device("cpu"),
    epsilon: float = 0.05,
    capture_video: bool = True,
):
    envs = gym.vector.SyncVectorEnv([make_env(env_id, 0, 0, capture_video, run_name)])
    model = Model(envs).to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    obs, _ = envs.reset()
    episodic_returns = []
    while len(episodic_returns) < eval_episodes:
        if random.random() < epsilon:
            actions = np.array(
                [envs.single_action_space.sample() for _ in range(envs.num_envs)]
            )
        else:
            q_values = model(torch.Tensor(obs).to(device))
            actions = torch.argmax(q_values, dim=1).cpu().numpy()
        next_obs, _, _, _, infos = envs.step(actions)
        if "final_info" in infos:
            for info in infos["final_info"]:
                if "episode" not in info:
                    continue
                print(
                    f"eval_episode={len(episodic_returns)}, episodic_return={info['episode']['r']}"
                )
                episodic_returns += [info["episode"]["r"]]
        obs = next_obs

    return episodic_returns

# %%
if args.save_model:
    model_path = f"runs/{run_name}/{args.exp_name}.cleanrl_model"
    torch.save(q_network.state_dict(), model_path)
    print(f"model saved to {model_path}")

    episodic_returns = evaluate(
        model_path,
        make_env,
        args.env_id,
        eval_episodes=10,
        run_name=f"{run_name}-eval",
        Model=QNetwork,
        device=device,
        epsilon=0.05,
    )
    for idx, episodic_return in enumerate(episodic_returns):
        writer.add_scalar("eval/episodic_return", episodic_return, idx)

    if args.upload_model:
        from cleanrl_utils.huggingface import push_to_hub

        repo_name = f"{args.env_id}-{args.exp_name}-seed{args.seed}"
        repo_id = f"{args.hf_entity}/{repo_name}" if args.hf_entity else repo_name
        push_to_hub(
            args,
            episodic_returns,
            repo_id,
            "DQN",
            f"runs/{run_name}",
            f"videos/{run_name}-eval",
        )

    envs.close()
    writer.close()
# Out:
# model saved to runs/CartPole-v1__dqn__1__1732480334/dqn.cleanrl_model
# /tmp/ipykernel_3383599/1852147759.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# /home/emasuriano/Git/rn-group-7/rl-demos/.venv/lib/python3.10/site-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /home/emasuriano/Git/rn-group-7/rl-demos/.venv/lib/python3.10/site-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /home/emasuriano/Git/rn-group-7/rl-demos/.venv/lib/python3.10/site-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# Moviepy - Building video /home/emasuriano/Git/rn-group-7/rl-demos/dqn/videos/CartPole-v1__dqn__1__1732480334-eval/rl-video-episode-0.mp4.
# Moviepy - Writing video /home/emasuriano/Git/rn-group-7/rl-demos/dqn/videos/CartPole-v1__dqn__1__1732480334-eval/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /home/emasuriano/Git/rn-group-7/rl-demos/dqn/videos/CartPole-v1__dqn__1__1732480334-eval/rl-video-episode-0.mp4
# eval_episode=0, episodic_return=[293.]
# Moviepy - Building video /home/emasuriano/Git/rn-group-7/rl-demos/dqn/videos/CartPole-v1__dqn__1__1732480334-eval/rl-video-episode-1.mp4.
# Moviepy - Writing video /home/emasuriano/Git/rn-group-7/rl-demos/dqn/videos/CartPole-v1__dqn__1__1732480334-eval/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /home/emasuriano/Git/rn-group-7/rl-demos/dqn/videos/CartPole-v1__dqn__1__1732480334-eval/rl-video-episode-1.mp4
# eval_episode=1, episodic_return=[279.]
# eval_episode=2, episodic_return=[266.]
# eval_episode=3, episodic_return=[255.]
# eval_episode=4, episodic_return=[300.]
# eval_episode=5, episodic_return=[387.]
# eval_episode=6, episodic_return=[417.]
# eval_episode=7, episodic_return=[238.]
# Moviepy - Building video /home/emasuriano/Git/rn-group-7/rl-demos/dqn/videos/CartPole-v1__dqn__1__1732480334-eval/rl-video-episode-8.mp4.
# Moviepy - Writing video /home/emasuriano/Git/rn-group-7/rl-demos/dqn/videos/CartPole-v1__dqn__1__1732480334-eval/rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready /home/emasuriano/Git/rn-group-7/rl-demos/dqn/videos/CartPole-v1__dqn__1__1732480334-eval/rl-video-episode-8.mp4
# eval_episode=8, episodic_return=[243.]
# eval_episode=9, episodic_return=[334.]
